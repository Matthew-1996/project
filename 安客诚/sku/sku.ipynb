# %%
#-*- coding:utf-8 -*-
import pandas as pd
#为了方便，在运行前先把SKU LOCALNAME改成SKU_LOCALNAME（sku表）, SKU CODE改成SKU_CODE(两张表)

# %%
filename = 'SKU-06010.txt'
sku_dataset = pd.read_table(filename)
filename2 = '资料_商品整理表test.txt'
sku_zl = pd.read_table(filename2)

# %%
zl_code = list(sku_zl['SKU_CODE'])
sku_dataset = sku_dataset[~sku_dataset.SKU_CODE.isin(zl_code)]

sku_dataset['CATEGORYCH'] = sku_dataset['CATEGORYCH'].apply(str)
sku_dataset = sku_dataset[~sku_dataset.CATEGORYCH.str.contains('彩妆|脸部护理')]
sku_dataset['SKU_LOCALNAME'] = sku_dataset['SKU_LOCALNAME'].apply(str)
sku_dataset = sku_dataset[~sku_dataset.SKU_LOCALNAME.str.contains('随机|换购|葡萄籽|玻尿酸|券|肌底液|紧肤水|卸妆|海报|腮红|睫毛|眼线|眼影|眉笔|档|化妆|青春密码|唇膏|唇釉|唇彩|唇线笔|甲油|美甲|粉饼|遮瑕|隔离|粉底|水活喷雾|彩妆|彩装|美颜液|白护|复颜|美白|肌底|自由来|沁润|凝养|雪颜|纤体|清润|恒放|魅力|风盈|清盈|盈爽|时尚珍藏|臻颜|创世|科研|矿物净化|卡片|卡贴|立牌|明信片')]
sku_dataset
# Out:
#         SKU ID  SKU_CODE            SKU INTLNAME SKU_LOCALNAME  Unnamed: 4  \
# 784      879.0  P0100312           GIFT FOR 1500       1500分赠品         NaN
# 785      880.0  P0100313           GIFT FOR 2500       2500分赠品         NaN
# 786      881.0  P0100314           GIFT FOR 3500       3500分赠品         NaN
# 787      882.0  S0000001        L'OREAL GIFT BOX         欧莱雅礼盒         NaN
# 788      883.0  S0000002  L'OREAL GIFT BOX (BIG)      欧莱雅礼盒(大)         NaN
# ...        ...       ...                     ...           ...         ...
# 46449  49565.0   MU71102                   DUMMY         DUMMY         NaN
# 46450  49566.0   MU71103                   DUMMY         DUMMY         NaN
# 46451  49567.0    G10145                   DUMMY         DUMMY         NaN
# 46452  49568.0    G10146                   DUMMY         DUMMY         NaN
# 46453      NaN       NaN                     NaN           nan         NaN
#
#        SKU PRICE  PRD ID PRD INTLNAME PRD LOCALNAME PRD SHORTDESC  LIN ID  \
# 784          0.0    38.0     Gift Box            礼盒   Gift Box 礼盒    28.0
# 785          0.0    38.0     Gift Box            礼盒   Gift Box 礼盒    28.0
# 786          0.0    38.0     Gift Box            礼盒   Gift Box 礼盒    28.0
# 787         25.0    38.0     Gift Box            礼盒   Gift Box 礼盒    28.0
# 788         30.0    38.0     Gift Box            礼盒   Gift Box 礼盒    28.0
# ...          ...     ...          ...           ...           ...     ...
# 46449        0.0   219.0        DUMMY         DUMMY   DUMMY DUMMY     NaN
# 46450        0.0   219.0        DUMMY         DUMMY   DUMMY DUMMY     NaN
# 46451        0.0   219.0        DUMMY         DUMMY   DUMMY DUMMY     NaN
# 46452        0.0   219.0        DUMMY         DUMMY   DUMMY DUMMY     NaN
# 46453        NaN     NaN          NaN           NaN           NaN     NaN
#
#       FRANCHISEEN FRANCHISECH  PCT ID CATEGORY CATEGORYEN CATEGORYCH  \
# 784      Gift Box    Gift Box              0.0     Others         其他
# 785      Gift Box    Gift Box              0.0     Others         其他
# 786      Gift Box    Gift Box              0.0     Others         其他
# 787      Gift Box    Gift Box              0.0     Others         其他
# 788      Gift Box    Gift Box              0.0     Others         其他
# ...           ...         ...              ...        ...        ...
# 46449         NaN         NaN              NaN        NaN        nan
# 46450         NaN         NaN              NaN        NaN        nan
# 46451         NaN         NaN              NaN        NaN        nan
# 46452         NaN         NaN              NaN        NaN        nan
# 46453         NaN         NaN              NaN        NaN        nan
#
#        PCT ID ROUTINE ROUTINEEN ROUTINECH
# 784               0.0    Others        其他
# 785               0.0    Others        其他
# 786               0.0    Others        其他
# 787               0.0    Others        其他
# 788               0.0    Others        其他
# ...               ...       ...       ...
# 46449             NaN       NaN       NaN
# 46450             NaN       NaN       NaN
# 46451             NaN       NaN       NaN
# 46452             NaN       NaN       NaN
# 46453             NaN       NaN       NaN
#
# [33701 rows x 19 columns]

# %%
sku_dataset.to_csv(path_or_buf = r'C:\Users\mye\Desktop\jupyter\test.csv', encoding="utf_8_sig")
